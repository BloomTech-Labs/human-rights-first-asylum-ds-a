# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from typing import List, Tuple, Union, Callable, Dict, Iterator
from collections import defaultdict
from difflib import SequenceMatcher
import spacy 
from spacy.matcher import Matcher, PhraseMatcher
from spacy.tokens.doc import Doc
from spacy.tokens.span import Span
from spacy.tokens.token import Token

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### There are very few initial cases to work with, here there are 17. Most of our cases are appeals cases, where you can search for panel members, not initial case judges. Cases 175361890, 309306110, 318845018, and 349320269, are initial cases from our current set of cases, while the other 13 came from [here](https://drive.google.com/drive/folders/1_1MLtL3pm-05cff7piUFMLKsMUeubVmX).

# %%
filenames = os.listdir('./HRF_original_decisions_txt') # Wherever files are located

# %% [markdown]
# ### This scrapes a link for a list of immigration judges (not panel members). This is unreliable, and a list of judges should probably be handled with the backend.

# %%
judges_url = 'https://www.justice.gov/eoir/eoir-immigration-court-listing#MP' # url containing judge names
html = requests.get(judges_url).text # get html text
soup = BeautifulSoup(html, 'html.parser') # parse html with bs4
tables = soup.find_all("tbody") # get all tables

# %%
judge_list = [] # initialize judge name list
for table in tables: # iterate through each table
    for judges in table.find_all('tr')[2:]: # iterate through each row of each table skipping first two rows
        judge_list.extend(list(judges)[4].get_text().strip().replace('\t', '').split('\n')) # get and clean text from judge names cell in each row
        
len(judge_list)
# Out:
# 491

# %% [markdown]
# ### Reformat the names to have the first name first since this is how they are found in the case documents.

# %%
judges = []
for judge in judge_list:
    judges.append(' '.join(reversed(judge.split(', '))))
    print(' '.join(reversed(judge.split(', '))))
# Out:
# John W. Cortes
# Jennifer I. Gaz
# Paul Habich
# Jose L. Penalosa Jr.
# Molly S. Frazer
# Marni Guerrero
# Bruce A. Taylor
# Robert C. Bartlemay Sr.
# Elizabeth A. Cottor
# LaMonte S. Freerks
# Joseph S. Imburgia
# Ken Josephson
# Melissa B. Karlen
# Munish Sharda
# Linda Spencer-Walters
# John W. Davis
# Kathryn L. DeAngelis
# Sean H. Keenan
# Lauren Mathon
# Ravit R. Halperin
# Steven Marcus
# Nathaniel B. Walker
# Curtis G. White
# Jeffrey V. Muñoz
# Christian Pressman
# Eugene H. M. Robinson
# Nathan N. Aina
# Lily C. Hsu
# James M. Left
# Kristin Piepmeier
# Frank Travieso
# Janette L. Allen
# Joyce Bakke Varzandeh
# Ira Bank
# Audra Behne
# Hye Y. Chon
# Philip Costa
# Jankhana Desai
# Timothy Everett
# Leon J. Francis
# Andrea H. Hong
# Natalie B. Huddleston
# Jaime Jasso
# Carlos R. Juelle
# Jan D. Latimore
# Edward F. Lee
# Wilbur Lee
# Daniel H. Malvin
# Nancy E. Miller
# Jeannette Lim Park
# Sebastian T. Patti
# Rachel Ann Ruane
# Anita L. Simons
# Christine E. Stancill
# Gita Vahid-Tehrani
# Veronica S. Villegas
# Bridget Virchis
# Jason R. Waterloo
# Brian H. Burke
# David Burke
# Arlene Dorfman
# Carlos Maury
# Tara Naselow-Nahas
# Sandra Santos-Garcia
# Amelia C. Anderson
# Samantha L. Begovich
# Valerie A. Burch
# Catherine E. Halliday-Roberts
# Ana L. Partida
# Loreto Geisse
# Print Maggard
# William Neumeister
# Christopher V. Phan
# Gilda M. Terrazas
# Olga Attia
# James DeVitto
# Guy G. Grande
# Philip S. Law
#  Lee O'Connor
# Jeffrey L. Romig
# Scott Simpson
# Jeremy J. Butler
# Andrew J. Caborn
# Ila C. Deiss
# Laura C. Figueroa
# Scott D. Gambill
# Amber D. George
# III Charles S. Greene
# Jacqueline J. Jackson
# Jeremiah Johnson
# Samuel Y. Kim
# Kelly B. Lake
# Anna C. Little
# Dana Leigh Marks
# Jason R. Masterson
# Julie L. Nelson
# Patrick S. O’Brien
# Joseph Y. Park
# Susan Phan
# Cory M. Picton
# Justin M. Price
# Patrick S. Savage
# Gregory L. Simmons
# Shadee M. Star
# Arwen A. Swink
# Elizabeth L. Young
# Steven Caley
# Nina M. Carbone
# Elizabeth McGrail
# Brea C. Burgie
# Kerri A. Calcador
# Melanie K. Corrin
# Ivan E. Gardzelewski
# Alison R. Kane
# Matthew W. Kaufman
# Donald C. O’Hare
# Eileen R. Trujillo
# Daniel A. Morris
# Michael W. Straus
# Philip Verrillo
# Scott G. Alexander
# Michelle C. Araneta
# Thomas M. Ayze
# Javier Balasquide
# Charlotte D. Brown
# Abraham L. Burgess
# Timothy M. Cole
# J. Daniel Dowell
# Madeline Garcia
# Lakshmi Srinivasan Herman
# Dalin R. Holyoak
# Michael C. Horn
# Denise A. Marks Lane
# Anthony Maingot
# Stephen E. Mander
# Lourdes Martinez-Esquivel
# Rene Mateo
# Ian D. Midgley
# Marsha K. Nettles
# Irene M. Recio
# Jose A. Rivera-Ortiz
# Lourdes Rodriquez de Jongh
# Rico M. Sogocio
# Lilliana Torreh-Bayouth
# Gabriel C. Videla
# Michael G. Walleisa
# Barry S. Chait
# Maria Lopez-Enriquez
# Christina Martyak
# Jorge L. Pereira
# Stuart Siegel
# Yon K. Alberdi
# Victoria L. Ghartey
# James K. Grim
# Monique Harris
# Stuart F. Karden
# Jennifer L. Page-Lozano
# Scott D. Criss
# James J. Crofts
# Randall W. Duncan
# Sheila E. Gallow
# Phillip A. Barr
# Blake L. Doughty
# Ryan A. Fisher
# John M. Gillies
# Njeri B. Maldonado
# Daniel J. Redwood
# Michael A. Schnitzer
# Phillip P. Taylor
# Bianca H. Brown
# Jeffrey R. Nance
# Jerome M. Rothschild Jr.
# Dan Trimble
# Jesus Clemente
# Clarence Wagner
# Samuel B. Cole
# Brendan Curran
# Craig A. Defoe
# Eliza Klein
# Michael P. Klosowsky
# Elizabeth G. Lang
# Joshua D. Luskin
# Patrick M. McKenna
# Samia Naseem
# Jennifer I. Peyton
# Robin Rosche
# Kaarina Salovaara
# Eva S. Saltzman
# Kelly S. Johnson
# Daniel P. Kinnicutt
# H. Kevin Mart
# Robert Q. Ward
# Steven B. Fuller
# Brent H. Landis
# Angela Munson
# Cassie A. Thorgersen
# Joseph B. La Rocca
# Charlotte S. Marquez
# Eric W. Marsteller
# Sherron Ashworth
# John A. Duck Jr.
# W. Scott Laragy
# David W. Crosland
# Elizabeth A. Kessler
# David C. Koelsch
# Zakia Mahasa
# Nelson A. Vargas-Padilla
# Dinesh C. Verma
# Jack Weil
# Phillip T. Williams
# Robin Feder
# John M. Furlong Jr.
# Paul M. Gagnon
# Todd A. Masters
# Brenda O'Malley
# Maureen O'Sullivan
# Marna M. Rusher
# Mario J. Sturla
# Gwendylan Tregerman
# Jennifer M. Gorland
# Mark J. Jebson
# David H. Paruch
# Ian R. Simons
# M. Audrey Carr
# Joseph Dierkes
# Katherine L. Hansen
# Sarah Mazzie
# Monte G. Miller
# Brian Sardelli
# Justin W. Howard
# Colin P. Johnson
# Jayme Salinardi
# Alexandra Larsen
# Abby L. Meyer
# Matthew E. Morrissey
# Glen R. Baker
# Ann M. McDermott
# An Nguyen
# Lindsy M. Roberts
# Jason L. Pope
# Pallavi S. Shirole
# Mirlande Tadal
# Shana W. Chen
# David Cheng
# Leo A. Finston
# Denise A. Hinds Roach
# Amanda R. Jeannopoulos
# Leila A. Mullican
# Alan Page
# Laura Pierro
# Arya S. Ranasinghe
# Ramin Rastegar
# Alberto J. Riefkohl
# Shifra Rubin
# Tamar H. Wilson
# Lorely Ramirez Fernandez
# Kathy French
# Ralph E. Girvin Jr.
# Jacinto Palomino
# Brock E. Taylor
# Susan F. Aikman
# Robert P. Driscoll
# Mary C. Baumgarten
# Steven Connelly
# Denise Hochul
# Walter H. Ruehle
# Kyung S. Auh
# Erin L. Alexander
# J. Thomas Bartleson
# John P. Burns
# Andrew M. Calvelli
# Jesse. Christensen
# Jennifer Chung
# Diane L. Dodd
# Robert J. Gundlach
# Edward P. Grogan
# Andrea Koppenhofer
# Dawn M. Kulick
# Carolyn L. Krasinski
# Brigitte Laforest
# Shirley Lazare-Raphael
# Tanawa Lebreton
# Michael W. Lloyd
# James M. McCarthy
# James R. McKee
# Maria Navarro
# Aviva Poczter
# Noel A. Brennan
# Lorianne M. Campanella
# Olivia L. Cassin
# Amit Chugh
# Raisa Cohen
# Evalyn P. Douchy
# L. Batya Schwartz Ehrens
# Samuel M. Factor
# David A. Fraiden
# Lena Golovnin
# Cynthia Gordon
# Vivienne E. Gordon-Uruakpa
# Dorothy Harbeck
# Howard C. Hom
# Carrie Johnson-Papillo
# Amiena A. Khan
# Deborah E. Klahr
# Theodora N. Kouris
# Frederic G. Leeds
# F. James Loprest Jr.
# Maria Lurye
# Michael G. McFarland
# Barbara A. Nelson
# Brian T. Palmer
# Cathy Sagesse
# Douglas B. Schoppert
# Alice Segal
# John J. Siemietkowski
# Rantideva Singh
# Oshea Denise Spencer
# Jem C. Sponzo
# Scott E. Thomsen
# Donald Thompson
# Mimi Tsankov
# Maria T. Ubarri
# Virna Wright
# Randa Zagzoug
# Roger Sagerman
# Ubaid ul-Haq
# Shayne R. Burnham
# Charles R. Conroy
# Richard H. Drucker
# Lauren F. Farber
# Forrest W. Hoover III
# Margaret Kolbe
# Lisa W. Ling
# Thomas Mulligan
# Thomas J. Mungoven
# David A. Norkin
# Francisco R. Prieto
# Dara F. Reid
# Rodger C. Harris
# Amy Lee
# George W. (William) Riggs
# Jesus Clemente
# Clarence Wagner
# Monte J. Horton
# Bruce D. Imbacuan
# Jonathan W. Owens
# Donald Pashayan
# Jennifer M. Riedthaler-Williams
# Teresa L. Riley
# Jeremy J. Santoro
# Michael A. Tripi
# David C. Whipple
# Mindy E. Hoeppner
# Richard M. Zanfardino
# John B. Carle
# Patrick J. Ehlers
# Annie S. Garcy
# Mary C. Lee
# Rosalind K. Malloy
# Steven Morley
# Joseph C. Scott
# Kuyomars Golparvar
# Alice Song Hartye
# Matthew H. Watters
# Julia Diaz-Rex
# Pedro J. Espinal
# Elvin R. Talavera-Peraza
# Rebecca L. Holt
# Luis A. Maldonado
# David A. Russo
# Brisack,Chris A.
# Holly A. D'Andrea
# Mark S. Evans
# Powell,Robert L.
# Billy J. Sapp
# Xiomara D. Davis-Gumbs
# Jason D. Ferguson
# Glen R. Hines
# R. Wayne Kimball
# James A. Nugent
# Richard R. Ozmun
# Virginia Perez-Guzman
# Deitrich H. Sims
# Christopher J. Thielemann
# Judith F. Bonilla
# Nathan L. Herbert
# James J. Miller Jr.
# William L. Abbott
# Michael S. Pleters
# Stephen Ruhle
# Dean S. Tuckman
# Jacob D. Bashore
# John G. Crews II
# Donald R. Eller Jr.
# Sarah M. Ellison
# Randall L. Fluke
# Kelley N. Fowler
# D'Anna H. Freeman
# Monica Thompson Guidry
# Brandon L. Hart
# Richard C. Jacobs
# Allan F. John-Baptiste
# Hugo R. Martinez
# Jennifer A. May
# Shelly W. Schools
# Howard Achtsam
# Mark K. Brooks
# Sean D. Clancy
# Delia I. González
# Joseph T. Leonard
# Nimmo Bhagat
# Sam Brown IV
# Gary E. Endelman
# Marcos Gemoets
# Saul E. Greenstein
# Richard A. Jamadar
# Anwer A. Khan
# Erica J. McGuirk
# Bao Q. Nguyen
# Joshua D. Osborn
# Georgina M. Picos
# Richard D. Walton
# Lynn W. Wang
# Monica T. Guidry
# Brent H. Landis
# Erica J. McGuirk
# Oshea D. Spencer
# Kevin L. Brown
# Miguel A. Cordero-Gonzalez
# Charissa S. Dvorak
# Arkesia S. Jenkins
# DeLana M. Jones
# John W. McPhail
# Christopher M. Schumann
# Kenley J. Thompson
# Clarease Rankin Yates
# Stuart D. Alcorn
# Elizabeth Martinez
# Robert Reid McKee
# Walter L. "Bud" Paulissen
# Julian Castaneda
# Barbara Gonzalez Cigarroa
# Paul A. Hable
# Morris I. Onyewuchi
# Frank T. Pimentel
# Justin Adams
# Margaret D. Burkhart
# Thomas G. Crossan Jr.
# Yvonne S. Gonzalez
# Craig A. Harlow
# Cynthia Lafuente-Gaona
# Clay N. Martin
# Anibal D. Martinez
# Charles M. McCullough
# Rifian S. Newaz
# Daniel J. Santander
# Eric J. Tijerina
# Meredith Tyrakoski
# David C. Anderson
# Christopher M. Greer
# Phillip M. Truman
# John Cody Barnes
# John M. Bryant
# Lawrence O. Burman
# Raphael Choi
# Roxanne C. Hladylowycz
# Wynne P. Kelly
# Lolita M. Lukose
# Elise Manuel
# Paul A. McCloskey
# Francisco Mendez
# Deepali Nadkarni
# Matthew J. O’Brien
# Helaine R. Perlman
# Emmett D. Soper
# Karen D. Stevens
# Cynthia Shepherd Torg
# David White
# Lisa De Cardona
# Emily N. Farrar-Crockett
# Robert M. Lewandowski
# Nicholas A. Martz
# George J. Ward Jr.
# David W. Evans
# Shane E. Johnson
# Robert B.C. McSeveney
# Brett M. Parchert
# Hayden Windrow
# Tammy Fitting
# Charles Neil Floyd
# John C. Odell

# %% [markdown]
# ### Instantiate a matcher, and add each judge's name as a pattern to search for in a document.

# %%
matcher = PhraseMatcher(nlp.vocab)

for judge in judges:
    # Add the pattern to the matcher
    matcher.add(f'PATTERN_{judge}', [nlp(judge)])

# %% [markdown]
# ### Go through the documents and search for matches with judges in our list, using the same logic as `get_panel()` does to search for panel members, except with a different list of judges.

# %%
matcher_dict = {}

for file in filenames:
    if file != '.DS_Store': # mac added this, ugh, so make sure it isn't this file
        f = open(f"./HRF_original_decisions_txt/{file}", "r")
        print(file)
        doc = nlp(f.read())
        f.close()

        matches = matcher(doc)
        possible_judges = set()

        if len(matches) > 0:
            for match_id, start, end in matches:
                judge = doc[start:end]
                possible_judges.add(judge.text)

        matcher_dict[file] = "; ".join(possible_judges)
# Out:
# 175361890-Jose-Zacaria-Quinteros-A088-239-850-BIA-Mar-31-2011-output-1-to-9.txt
# IJ Decision in another UB Case w serious non-political crime issues_REDACTED-output-1-to-22.txt
# Honduran Women, Redacted Asylum Grant, Arlington VA-output-1-to-16.txt
# Redacted Grant, PSG Guatemalan Women-output-1-to-19.txt
# Chicago Immigration Judge - Post-AB Domestic Violence Based Grant of Asylum-output-1-to-9.txt
# Nicaragua - DV - IJ Rubin Newark, NJ (2020)-output-1-to-12.txt
# 2020.02.19 Asylum grant_Redacted-output-1-to-15.txt
# Redacted IJ Decision %22single Salvadoran mothers lacking male protection%2225072018 (1)-output-1-to-10.txt
# Redacted_IJ Decision_Asylum grant for false gang alleg PSG (1)-output-1-to-17.txt
# Family PSGAnti-gangPO - IJ Feder 9.18.19_Redacted (1)-output-1-to-14.txt
# El Salvador - US labeled gang members - IJ Rubin Newark, NJ (2020)-output-1-to-17.txt
# Honduras.Women in domestic relationships asylum grant -Redacted-output-1-to-28.txt
# Asylum Grant Honduran Business Owners-output-1-to-50.txt
# IJ decision Brazilian National (9th Cir.)-output-1-to-13.txt
# 318845018-Ennio-Edgardo-Galvez-A095-006-115-BIA-July-5-2016-output-1-to-8.txt
# 309306110-Sergio-Maldonado-A078-567-541-BIA-March-21-2016-output-1-to-7.txt
# Honduran Garifuna Asylum Grant IJ Laforest - NY (2019)-output-1-to-7.txt
# 349320269-S-D-AXXX-XXX-230-BIA-April-26-2017-output-1-to-8.txt

# %%
df_matcher = pd.DataFrame(matcher_dict.items(), columns=['case', 'judge'])
df_matcher
# Out:
#                                                  case                  judge
# 0   175361890-Jose-Zacaria-Quinteros-A088-239-850-...
# 1   IJ Decision in another UB Case w serious non-p...
# 2   Honduran Women, Redacted Asylum Grant, Arlingt...         Wynne P. Kelly
# 3   Redacted Grant, PSG Guatemalan Women-output-1-...
# 4   Chicago Immigration Judge - Post-AB Domestic V...
# 5   Nicaragua - DV - IJ Rubin Newark, NJ (2020)-ou...           Shifra Rubin
# 6   2020.02.19 Asylum grant_Redacted-output-1-to-1...       David C. Koelsch
# 7   Redacted IJ Decision %22single Salvadoran moth...
# 8   Redacted_IJ Decision_Asylum grant for false ga...
# 9   Family PSGAnti-gangPO - IJ Feder 9.18.19_Redac...
# 10  El Salvador - US labeled gang members - IJ Rub...
# 11  Honduras.Women in domestic relationships asylu...
# 12  Asylum Grant Honduran Business Owners-output-1...
# 13  IJ decision Brazilian National (9th Cir.)-outp...        Molly S. Frazer
# 14  318845018-Ennio-Edgardo-Galvez-A095-006-115-BI...            Lily C. Hsu
# 15  309306110-Sergio-Maldonado-A078-567-541-BIA-Ma...  Clarease Rankin Yates
# 16  Honduran Garifuna Asylum Grant IJ Laforest - N...      Brigitte Laforest
# 17  349320269-S-D-AXXX-XXX-230-BIA-April-26-2017-o...

# %% [markdown]
# # 7 out of 17 is pretty bad!
