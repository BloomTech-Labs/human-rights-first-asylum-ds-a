# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from typing import List, Tuple, Union, Callable, Dict, Iterator
from collections import defaultdict
from difflib import SequenceMatcher
import spacy 
from spacy.matcher import Matcher, PhraseMatcher
from spacy.tokens.doc import Doc
from spacy.tokens.span import Span
from spacy.tokens.token import Token

# %%
nlp = spacy.load("en_core_web_sm")

# %%
filenames = os.listdir('./hrfCases') # Wherever files are located

# %% [markdown]
# #### `similar()` and `similar_in_list()` are the current search methods for finding panel members within a case.

# %%
def similar(a: str, return_b: str, min_score: float) -> Union[str, None]:
    """
    • Returns 2nd string if similarity score is above supplied
    minimum score. Else, returns None.
    """
    if SequenceMatcher(None, a, return_b).ratio() >= min_score:
        return return_b


def similar_in_list(lst: Union[List[str], Iterator[str]]) -> Callable:
    """
    • Uses a closure on supplied list to return a function that iterates over
    the list in order to search for the first similar term. It's used widely
    in the scraper.
    """

    def impl(item: str, min_score: float) -> Union[str, None]:
        for s in lst:
            s = similar(item, s, min_score)
            if s:
                return s

    return impl

# %% [markdown]
# #### `members` is a hard-coded list of judges emulating a stored list, which is preferred over making requests to what could be unreliable links. I made this list from our previous list, and our correct manually extracted panel members.

# %%
members = [
    "Adkins-Blanch, Charles K.",
    "Michael P. Baird",
    "Cassidy, William A.",
    "Cole, Patricia A.",
    "Couch, V. Stuart",
    "Creppy, Michael J.",
    "Crossett, John P.",
    "Donovan, Teresa L.",
    "Foote, Megan E.",
    "Geller, Joan B.",
    "Gemoets, Marcos",
    "Gonzalez, Gabriel",
    "Goodwin, Deborah K.",
    "Gorman, Stephanie E.",
    "Grant, Edward R.",
    "Greer, Anne J.",
    "Guendelsberger, John",
    "Hunsucker, Keith E.",
    "Kelly, Edward F.",
    "Kendall Clark, Molly",
    "Liebmann, Beth S.",
    "Liebowitz, Ellen C.",
    "Mahtabfar, Sunita B.",
    "Malphrus, Garry D.",
    "Mann, Ana",
    "Miller, Neil P.",
    "Monsky, Megan Foote",
    "Montante Jr., Phillip J.",
    "Morris, Daniel",
    "Mullane, Hugh G.",
    "Neal, David L.",
    "Noferi, Mark",
    "O'Connor, Blair",
    "O'Herron, Margaret M.",
    "O'Leary, Brian M.",
    "Owen, Sirce E.",
    "Pauley, Roger",
    "Petty, Aaron R.",
    "Pepper, S. Kathleen",
    "RILEY, KEVIN W.",
    "Rosen, Scott",
    "Snow, Thomas G.",
    "Swanwick, Daniel L.",
    "Wendtland, Linda S.",
    "Wetmore, David H.",
    "Wilson, Earle B."
]

# %%
len(members)
# Out:
# 46

# %% [markdown]
# #### Here we'll grab our currently implemented list for testing of potential panel members from Wikipedia, which has only 29 judges, and even though they are repeated in the list above, they are ordered differently, namely from first name to last name, which contributes to more patterns for matching.

# %%
judges_url = 'https://en.wikipedia.org/wiki/Board_of_Immigration_Appeals'
html = requests.get(judges_url).text
soup = BeautifulSoup(html, 'html.parser')
table = soup.find("table", class_="wikitable")
web_judges = [itm.get_text().strip() for itm in table.select("td")[1::4]]

web_judges
# Out:
# ['David H. Wetmore',
#  'Charles Adkins-Blanch',
#  'Garry D. Malphrus',
#  'Michael P. Baird',
#  'William A. Cassidy',
#  'V. Stuart Couch',
#  'Michael J. Creppy',
#  'Deborah K. Goodwin',
#  'Stephanie E. Gorman',
#  'Edward R. Grant',
#  'Anne J. Greer',
#  'Keith E. Hunsucker',
#  'Edward F. Kelly',
#  'Ellen Liebowitz',
#  'Sunita B. Mahtabfar',
#  'Ana Landazabal Mann',
#  'Philip J. Montante, Jr.',
#  'Hugh Mullane',
#  "Blair O'Connor",
#  'Sirce E. Owen',
#  'Aaron R. Petty',
#  'Kevin W. Riley',
#  'Earle B. Wilson',
#  'Megan Foote Monsky',
#  'Joan B. Geller',
#  'Gabriel Gonzalez',
#  'Beth Liebmann',
#  'Mark Noferi',
#  'S. Kathleen Pepper']

# %%
len(web_judges)
# Out:
# 29

# %% [markdown]
# #### Combining the lists gives us one big list of patterns to match

# %%
combined_members = members + web_judges
len(combined_members)
# Out:
# 75

# %% [markdown]
# #### Below is identical to the current code implemented, except for the alternating of `names` in the constructor for `GetJudge`, for which we will test the different lists.

# %%
class GetJudge:
    """ Returns the judge's name if a match is found. """
    accuracy = 0.7

    def __init__(self):
        # Currently grabs potential judges names from a URL here.
        # For testing we'll instead alternate `names`

#         names = web_judges
#         names = members
        names = combined_members
        self.is_judge: Callable = similar_in_list(names)

    def __call__(self, name):
        result = self.is_judge(name, self.accuracy)
        if not result:
            flip_name = ' '.join(reversed(name.split(', ')))
            result = self.is_judge(flip_name, self.accuracy)
        return result


class BIACase:
    def __init__(self, text: str):
        """
        • Input will be text from a BIA case pdf file, after the pdf has
        been converted from PDF to text.
        • Scraping works utilizing spaCy, tokenizing the text, and iterating
        token by token searching for matching keywords.
        """
        self.doc: Doc = nlp(text)
        self.ents: Tuple[Span] = self.doc.ents
        self.if_judge = GetJudge()

    def get_ents(self, labels: List[str]) -> Iterator[Span]:
        """
        • Retrieves entitiess of a specified label(s) in the document,
        if no label is specified, returns all entities
        """
        return (ent for ent in self.ents if ent.label_ in labels)

    def get_panel(self) -> str:
        """
        • Returns the panel members of case in document.
        """
        panel_members: List[str]
        panel_members = []
        possible_members: Iterator[Span]
        possible_members = map(
            lambda ent: ent.text, self.get_ents(['PERSON'])
        )
        for member in possible_members:
            judge: Union[str, None]
            judge = self.if_judge(member)
            if judge:
                panel_members.append(judge)

        return '; '.join(set(panel_members))

# %% [markdown]
# #### Helper function for pandas to count the number of members in a cell.

# %%
def num_members(x):
    if x != "":
        return len(x.split(';'))
    return 0

# %% [markdown]
# # Test list of judges from Wikipedia
# #### For each case, initialize a BIACase instance `case`, invoke the get_panel() method, and save the results to the filename in a dictionary.

# %%
# ** Change `names` to `web_judges` list in GetJudge() **
web_dict = {}

for file in filenames:
    f = open(f"./hrfCases/{file}", "r")
    case = BIACase(f.read())
    web_dict[file] = case.get_panel()
    f.close()

# %% [markdown]
# #### Create a dataframe from results dictionary `web_dict`

# %%
df_web = pd.DataFrame(web_dict.items(), columns=['case', 'members'])
df_web['num_members'] = df_web['members'].apply(num_members)
df_web.head()
# Out:
#                                                 case  \
# 0  414384746-W-S-Y-AXXX-XXX-857-BIA-June-6-2019-o...
# 1  437078509-Y-V-P-AXXX-XXX-977-BIA-Nov-6-2019-ou...
# 2  470811646-D-A-C-AXXX-XXX-366-BIA-June-12-2020-...
# 3  447698812-G-L-P-AXXX-XXX-275-BIA-Jan-22-2020-o...
# 4  386773053-A-A-H-AXXX-XXX-492-BIA-July-18-2018-...
#
#                           members  num_members
# 0  Hugh Mullane; Michael P. Baird            2
# 1                Michael P. Baird            1
# 2                                            0
# 3     Beth Liebmann; Hugh Mullane            2
# 4           Charles Adkins-Blanch            1

# %% [markdown]
# #### The list of judges pulled from Wikipedia, then searched for in our documents via the current implementation, results in finding 115 panel members for 170 cases.

# %%
df_web.num_members.sum()
# Out:
# 115

# %% [markdown]
# # Test hard-coded list of judges
# #### Same process as above, just using a different list of judges

# %%
# ** Change `names` to `members` list in GetJudge() **
local_dict = {}

for file in filenames:
    f = open(f"./hrfCases/{file}", "r")
    case = BIACase(f.read())
    local_dict[file] = case.get_panel()
    f.close()

# %%
df_local = pd.DataFrame(local_dict.items(), columns=['case', 'members'])
df_local['num_members'] = df_local['members'].apply(num_members)
df_local.head()
# Out:
#                                                 case           members  \
# 0  414384746-W-S-Y-AXXX-XXX-857-BIA-June-6-2019-o...  Michael P. Baird
# 1  437078509-Y-V-P-AXXX-XXX-977-BIA-Nov-6-2019-ou...  Michael P. Baird
# 2  470811646-D-A-C-AXXX-XXX-366-BIA-June-12-2020-...
# 3  447698812-G-L-P-AXXX-XXX-275-BIA-Jan-22-2020-o...
# 4  386773053-A-A-H-AXXX-XXX-492-BIA-July-18-2018-...
#
#    num_members
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0

# %% [markdown]
# #### The list of hard-coded judges, searched for in our documents via the current implementation, results in finding 69 panel members for 170 cases.

# %%
df_local.num_members.sum()
# Out:
# 69

# %% [markdown]
# # Test for a combined list of judges for more searchable patterns.

# %%
# ** Change `names` to `combined_members` list in GetJudge() **
combined_dict = {}

for file in filenames:
    f = open(f"./hrfCases/{file}", "r")
    case = BIACase(f.read())
    combined_dict[file] = case.get_panel()
    f.close()

# %%
df_combined = pd.DataFrame(combined_dict.items(), columns=['case', 'members'])
df_combined['num_members'] = df_combined['members'].apply(num_members)
df_combined.head()
# Out:
#                                                 case  \
# 0  414384746-W-S-Y-AXXX-XXX-857-BIA-June-6-2019-o...
# 1  437078509-Y-V-P-AXXX-XXX-977-BIA-Nov-6-2019-ou...
# 2  470811646-D-A-C-AXXX-XXX-366-BIA-June-12-2020-...
# 3  447698812-G-L-P-AXXX-XXX-275-BIA-Jan-22-2020-o...
# 4  386773053-A-A-H-AXXX-XXX-492-BIA-July-18-2018-...
#
#                           members  num_members
# 0  Hugh Mullane; Michael P. Baird            2
# 1                Michael P. Baird            1
# 2                                            0
# 3     Beth Liebmann; Hugh Mullane            2
# 4           Charles Adkins-Blanch            1

# %% [markdown]
# #### The combined list of judges, searched for in our documents via the current implementation, results in finding 165 panel members for 170 cases.

# %%
df_combined.num_members.sum()
# Out:
# 155

# %% [markdown]
# # Retrieve correct manually extracted data for comparison.

# %%
df_csv = pd.read_csv('cleaner_judges.csv')

# %%
# Drop rows that didn't put last name first (drops observation count from 170 to 110)
df_csv = df_csv[df_csv['YOUR NAME HERE'] != 'Josiah']
df_csv = df_csv[df_csv['YOUR NAME HERE'] != 'tori']
df_csv = df_csv[df_csv['YOUR NAME HERE'] != 'River']
df_csv = df_csv[df_csv['YOUR NAME HERE'] != 'Kevin']

# %%
len(df_csv)
# Out:
# 110

# %%
df_csv = df_csv[['UUID', 'panel members']]
df_csv['num_members'] = df_csv['panel members'].apply(num_members)
df_csv.columns = ['case', 'panel_members', 'num_panel_members']
df_csv.head()
# Out:
#                                                 case  \
# 0  140194281-Ali-Fares-A047-654-200-BIA-Apr-30-20...
# 1                165227167-K-O-A-BIA-Aug-27-2013.pdf
# 2  171952033-Luis-Narciso-Sedeno-Trujillo-A088-19...
# 3  175361890-Jose-Zacaria-Quinteros-A088-239-850-...
# 4  202216334-Francisco-Hernandez-Pina-A073-976-63...
#
#                                        panel_members  num_panel_members
# 0                                 Creppy, Michael J.                  1
# 1  Pauley, Roger; Wendtland, Linda S.; Donovan, T...                  3
# 2  Greer, Anne J.; Pauley, Roger; Wendtland, Lind...                  3
# 3  Greer, Anne J.; Pauley, Roger; Wendtland, Lind...                  3
# 4   Cole, Patricia A.; Greer, Anne J.; Pauley, Roger                  3

# %% [markdown]
# #### The csv of manual extracted data has 281 panel members for 110 cases.

# %%
df_csv.num_panel_members.sum()
# Out:
# 281

# %% [markdown]
# # Test Phrase Matcher
# #### Create `matcher` and add patterns. There are two patterns for each name, the first is the exact name as it is in the `members` list, which grabs 398 matches, and the other removes any periods, which grabs another 29 matches, for a total of 427.

# %%
matcher = PhraseMatcher(nlp.vocab)
counter = 0

for judge in members:
    matcher.add(f'PATTERN_{counter}', [nlp(judge)])
    matcher.add(f'PATTERNX_{counter}', [nlp(judge.replace(".",""))])
    counter += 1

# %%
matcher_dict = {}

for file in filenames:
    f = open(f"./hrfCases/{file}", "r")
    doc = nlp(f.read())
    f.close()
    
    matches = matcher(doc)
    p_members = set()
    
    if len(matches) > 0:
        for match_id, start, end in matches:
            judge = doc[start:end]
            p_members.add(judge.text)

    matcher_dict[file] = "; ".join(p_members)

# %%
df_matcher = pd.DataFrame(matcher_dict.items(), columns=['case', 'members'])
df_matcher['num_members'] = df_matcher['members'].apply(num_members)
df_matcher.head()
# Out:
#                                                 case  \
# 0  414384746-W-S-Y-AXXX-XXX-857-BIA-June-6-2019-o...
# 1  437078509-Y-V-P-AXXX-XXX-977-BIA-Nov-6-2019-ou...
# 2  470811646-D-A-C-AXXX-XXX-366-BIA-June-12-2020-...
# 3  447698812-G-L-P-AXXX-XXX-275-BIA-Jan-22-2020-o...
# 4  386773053-A-A-H-AXXX-XXX-492-BIA-July-18-2018-...
#
#                                              members  num_members
# 0               Malphrus, Garry D.; Mullane, Hugh G.            2
# 1             Malphrus, Garry D.; Liebowitz, Ellen C            2
# 2                                 Donovan, Teresa L.            1
# 3  Liebmann, Beth S.; Mullane, Hugh G.; Kelly, Ed...            3
# 4  Snow, Thomas G; Adkins-Blanch, Charles K.; Kel...            3

# %% [markdown]
# ### The phrase matcher finds 427 panel member for the 170 cases! Is this the right amount? To find out we merge the lists on case number to compare against the correct manually extracted data.

# %%
df_matcher.num_members.sum()
# Out:
# 427

# %% [markdown]
# #### Strip `case` down to number

# %%
df_matcher.case = df_matcher.case.apply(lambda x: x[:9])
df_csv.case = df_csv.case.apply(lambda x: x[:9])

# %% [markdown]
# #### Merge on `case`, resulting in 109 observations

# %%
df_merged = df_matcher.merge(df_csv, on='case')
df_merged.shape
# Out:
# (109, 5)

# %% [markdown]
# #### `num_members` is how many panel members the phrase matcher found, while `num_panel_members` is how many panel members were manually extracted for that case, for comparison.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df_merged
# Out:
#           case                                            members  \
# 0    470811646                                 Donovan, Teresa L.
# 1    386773053  Snow, Thomas G; Adkins-Blanch, Charles K.; Kel...
# 2    481527271                                 Creppy, Michael J.
# 3    398004870  Donovan, Teresa L.; Cole, Patricia A.; Greer, ...
# 4    470812246                    Gemoets, Marcos; Morris, Daniel
# 5    175361890  Pauley, Roger; Wendtland, Linda S.; Greer, Ann...
# 6    457375787  Greer, Anne J.; Swanwick, Daniel L.; Donovan, ...
# 7    225423441  Wendtland, Linda S.; Greer, Anne J.; Pauley, R...
# 8    334139459  Adkins-Blanch, Charles K.; Greer, Anne J.; O'H...
# 9    400015107                                   Kelly, Edward F.
# 10   470812759  Goodwin, Deborah K.; Donovan, Teresa L.; Wilso...
# 11   462825164                                Goodwin, Deborah K.
# 12   371997958  Adkins-Blanch, Charles K.; Grant, Edward R.; M...
# 13   481524010  Donovan, Teresa L.; Greer, Anne J.; Wilson, Ea...
# 14   470814353  Greer, Anne J.; Goodwin, Deborah K.; Donovan, ...
# 15   349321596  Pauley, Roger; Grant, Edward R.; Kelly, Edward F.
# 16   171952033  Pauley, Roger; Wendtland, Linda S.; Greer, Ann...
# 17   398005759  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 18   477308672  Goodwin, Deborah K.; Donovan, Teresa L.; Wilso...
# 19   393702763  Liebowitz, Ellen C; Malphrus, Garry D.; Mullan...
# 20   377420389   Greer, Anne J.; Crossett, John P.; Pauley, Roger
# 21   457373978  Liebmann, Beth S.; Rosen, Scott; Kelly, Edward F.
# 22   457374068  Gemoets, Marcos; Morris, Daniel; Liebowitz, El...
# 23   470814410  Swanwick, Daniel L.; Goodwin, Deborah K.; Gree...
# 24   470812076                                Pepper, S. Kathleen
# 25   402315262  Kelly, Edward F.; Adkins-Blanch, Charles K.; M...
# 26   400014991                          Adkins-Blanch, Charles K.
# 27   447700599      O'Connor, Blair; Noferi, Mark; Greer, Anne J.
# 28   473846393  Greer, Anne J.; Goodwin, Deborah K.; Donovan, ...
# 29   398005982  Kendall Clark, Molly; Adkins-Blanch, Charles K...
# 30   402309445  Mann, Ana; Adkins-Blanch, Charles K.; Kelly, E...
# 31   400017062  Wendtland, Linda S.; Cole, Patricia A.; Greer,...
# 32   400015130                                   Grant, Edward R.
# 33   398005224  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 34   322069426  O'Connor, Blair; Adkins-Blanch, Charles K.; O'...
# 35   328162186  Greer, Anne J.; Wendtland, Linda S.; Pauley, R...
# 36   462826415  Goodwin, Deborah K.; Donovan, Teresa L.; Wilso...
# 37   391518649  Wendtland, Linda S.; Crossett, John P.; Greer,...
# 38   377420845  Cole, Patricia A.; Greer, Anne J.; Crossett, J...
# 39   398214638  Pauley, Roger; Wendtland, Linda S.; Greer, Ann...
# 40   452087133                                 Creppy, Michael J.
# 41   447701547                                Goodwin, Deborah K.
# 42   395953588  Greer, Anne J.; Wendtland, Linda S.; Donovan, ...
# 43   389527101  Malphrus, Garry D.; Creppy, Michael J.; Hunsuc...
# 44   365733322  Liebowitz, Ellen C; Mullane, Hugh G.; Creppy, ...
# 45   400017191  Donovan, Teresa L.; Wendtland, Linda S.; Greer...
# 46   481527396  Donovan, Teresa L.; Goodwin, Deborah K.; Grant...
# 47   380078935                                   Grant, Edward R.
# 48   477308560  Goodwin, Deborah K.; Pepper, S. Kathleen; Dono...
# 49   470811394      Mullane, Hugh G.; Grant, Edward R.; Mann, Ana
# 50   398004575  O'Connor, Blair; Crossett, John P.; Greer, Ann...
# 51   165227167  Donovan, Teresa L.; Wendtland, Linda S.; Paule...
# 52   447702410                                   Kelly, Edward F.
# 53   374339687                                     Geller, Joan B
# 54   457376943  O'Connor, Blair; Donovan, Teresa L.; Greer, An...
# 55   380079140  Adkins-Blanch, Charles K.; Pauley, Roger; Snow...
# 56   457374430  Gemoets, Marcos; Liebowitz, Ellen C; Creppy, M...
# 57   354710999  Kendall Clark, Molly; Neal, David L; Adkins-Bl...
# 58   337540716  O'Connor, Blair; Adkins-Blanch, Charles K.; Ma...
# 59   477306913  Liebowitz, Ellen C; Creppy, Michael J.; Morris...
# 60   398005328                                   Grant, Edward R.
# 61   362583855  Kendall Clark, Molly; Greer, Anne J.; Kelly, E...
# 62   393702813  Snow, Thomas G; Adkins-Blanch, Charles K.; Gel...
# 63   462828871      Mullane, Hugh G.; Grant, Edward R.; Mann, Ana
# 64   337542906  O'Herron, Margaret M; Greer, Anne J.; Miller, ...
# 65   351906329  Liebowitz, Ellen C; Malphrus, Garry D.; Guende...
# 66   395953185  Kendall Clark, Molly; Guendelsberger, John; Ad...
# 67   477307335  Mullane, Hugh G.; RILEY, KEVIN W.; Grant, Edwa...
# 68   447700484                                Goodwin, Deborah K.
# 69   481529363  Donovan, Teresa L.; Goodwin, Deborah K.; Greer...
# 70   452101236             Liebowitz, Ellen C; Creppy, Michael J.
# 71   391517904  Wendtland, Linda S.; Crossett, John P.; Greer,...
# 72   371997582  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 73   452085302                                    O'Connor, Blair
# 74   473845983                    Gemoets, Marcos; Morris, Daniel
# 75   395953628  Wendtland, Linda S.; Crossett, John P.; Donova...
# 76   477308704  Donovan, Teresa L.; Pepper, S. Kathleen; Greer...
# 77   452085339                                   Grant, Edward R.
# 78   318845018                                   Grant, Edward R.
# 79   470813136                                   Wilson, Earle B.
# 80   208167027
# 81   462824675  Gemoets, Marcos; Liebowitz, Ellen C; Creppy, M...
# 82   271354416  Adkins-Blanch, Charles K.; Greer, Anne J.; Mil...
# 83   466552283  Swanwick, Daniel L.; Goodwin, Deborah K.; Wils...
# 84   452085561  Donovan, Teresa L.; Wendtland, Linda S.; Greer...
# 85   393704641  Kelly, Edward F.; Adkins-Blanch, Charles K.; G...
# 86   309306110  Guendelsberger, John; O'Leary, Brian M.; Grant...
# 87   398005367  Greer, Anne J.; Wendtland, Linda S.; Crossett,...
# 88   393703663  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 89   371996140  Greer, Anne J.; Wendtland, Linda S.; Pauley, R...
# 90   466549989                   O'Connor, Blair; Foote, Megan E.
# 91   478270188                                Pepper, S. Kathleen
# 92   337539141  Guendelsberger, John; Pauley, Roger; Geller, J...
# 93   382793281  Greer, Anne J.; Wendtland, Linda S.; Pauley, R...
# 94   481524478  O'Connor, Blair; Donovan, Teresa L.; Wilson, E...
# 95   311736830  Adkins-Blanch, Charles K.; Greer, Anne J.; O'H...
# 96   477307493  Gemoets, Marcos; Liebowitz, Ellen C; Creppy, M...
# 97   369893393  Cole, Patricia A.; Adkins-Blanch, Charles K.; ...
# 98   349320269  Liebowitz, Ellen C; Creppy, Michael J.; Mullan...
# 99   374338607                                   Grant, Edward R.
# 100  402310836  O'Connor, Blair; Malphrus, Garry D.; Donovan, ...
# 101  389525713  Greer, Anne J.; Wendtland, Linda S.; Crossett,...
# 102  473851235
# 103  205871959  Donovan, Teresa L.; Wendtland, Linda S.; Paule...
# 104  477307439           Goodwin, Deborah K.; Pepper, S. Kathleen
# 105  452083423                                       Noferi, Mark
# 106  481527566
# 107  393704112  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 108  202216334   Pauley, Roger; Cole, Patricia A.; Greer, Anne J.
#
#      num_members                                      panel_members  \
# 0              1                                 Donovan, Teresa L.
# 1              3  Adkins-Blanch, Charles K;  Kelly, Edward F.; S...
# 2              1  Creppy, Michael J.; MONSKY, MEGAN FOOTE; Hunsu...
# 3              3  Cole, Patricia A.; Greer, Anne J.; Donovan, Te...
# 4              2  Hunsucker, Keith; Gemoets, Marcos; Morris, Daniel
# 5              3  Greer, Anne J.; Pauley, Roger; Wendtland, Lind...
# 6              3  Donavan, Teresa L; Swanwick, Daniel L; Greer, ...
# 7              3  Wendtland, Linda S.; Greer, Anne J.; Pauley, R...
# 8              3  Greer, Anne J.; Adkins-Blanch, Charles K.; O'H...
# 9              1                                   Kelly, Edward F.
# 10             3  Goodwin, Deborah K; Donovan, Teresa L.; Wilson...
# 11             1                                 Goodwin, Deborah K
# 12             3  Grant, Edward R.; Adkins-Blanch, Charles K.; M...
# 13             3  Wilson, Earle B.; Greer, Anne J.; Donovan, Ter...
# 14             3  Goodwin, Deborah K; Donovan, Teresa L.; Greer,...
# 15             3   Kelly, Edward F. Grant, Edward R.; Pauley, Roger
# 16             3  Greer, Anne J.; Pauley, Roger; Wendtland, Lind...
# 17             3  Kendall Clark, Molly; Guendelsberger, John; Gr...
# 18             3  Wilson, Earle B.; Goodwin, Deborah K.; Donovan...
# 19             3  Liebowitz, Ellen C; Malphrus, Garry D.; Mullan...
# 20             3   Pauley, Roger; Greer, Anne J.; Crossett, John P.
# 21             3    Liebmann, Beth S; Kelly, Edward F; Rosen, Scott
# 22             3  Gemoets, Marcos; Morris, Daniel; Liebowitz, El...
# 23             3  Greer, Anne J.; Swanwick, Daniel L.; Goodwin, ...
# 24             1                                Pepper, S. Kathleen
# 25             3  Mann, Ana; Kelly, Edward F.; Adkins-Blanch, Ch...
# 26             1                          Adkins-Blanch, Charles K.
# 27             3      Noferi, Mark; O'Connor, Blair; Greer, Anne J.
# 28             3  Goodwin, Deborah K; Donovan, Teresa L.; Greer,...
# 29             3  Kendall Clark, Molly; Adkins-Blanch, Charles K...
# 30             3  Adkins-Blanch, Charles K.; Kelly, Edward F.; M...
# 31             3  Wendtland, Linda S.; Greer, Anne J.; Cole, Pat...
# 32             1                                   Grant, Edward R.
# 33             3  Guendelsberger, John; Grant, Edward R.; Kendal...
# 34             3  Adkins-Blanch, Charles K.; O'Connor, Blair; O'...
# 35             3  Pauley, Roger; Greer, Anne J.; Wendtland, Lind...
# 36             3  Wilson, Earle B.; Donovan, Teresa L.; Goodwin,...
# 37             3  Wendtland, Linda S.; Greer, Anne J.; Crossett,...
# 38             3  Cole, Patricia A; Greer, Anne J.; Crossett, Jo...
# 39             3  Greer, Anne J.; Pauley, Roger; Wendtland, Lind...
# 40             1                                  Creppy, Michael J
# 41             1                                 Goodwin, Deborah K
# 42             3  Donovan, Teresa L.; Greer, Anne J.; Wendtland,...
# 43             3  Malphrus, Garry D.; Creppy, Michael J.; Hunsuc...
# 44             3  Mullane, Hugh G.; Creppy, Michael J.; Liebowit...
# 45             3  Wendtland, Linda S.; Greer, Anne J.; Donovan, ...
# 46             3  Grant, Edward R.; Goodwin, Deborah K.; Donovan...
# 47             1                                   Grant, Edward R.
# 48             3  Goodwin, Deborah K.; Donovan, Teresa L.; Peppe...
# 49             3      Mullane, Hugh G.; Mann, Ana; Grant, Edward R.
# 50             3  Greer, Anne J.; O'Connor, Blair; Crossett, Joh...
# 51             3  Pauley, Roger; Wendtland, Linda S.; Donovan, T...
# 52             1                                    Kelly, Edward F
# 53             1                                    Geller, Joan B
# 54             3  Greer, Anne J; O'Connor, Blair; Donovan, Teresa L
# 55             3  Adkins-Blanch, Charles K.; Pauley, Roger; Snow...
# 56             3  Gemoets, Marcos; Creppy Michael J; Liebowitz, ...
# 57             3  Kendall Clark, Molly; Neal, David L; Adkins-Bl...
# 58             3  Adkins-Blanch, Charles K.; Mann, Ana; O'Connor...
# 59             3  Creppy, Michael J.; Liebowitz, Ellen C; Morris...
# 60             1                                   Grant, Edward R.
# 61             3  Greer, Anne J.; Kelly, Edward F.; Kendall Clar...
# 62             3  Adkins-Blanch, Charles K.; Geller, Joan B; Sno...
# 63             3      Mann, Ana; Grant, Edward R.; Mullane, Hugh G.
# 64             3  Greer, Anne J.; Miller, Neil P.; O'Herron, Mar...
# 65             3  Guendelsberger, John; Liebowitz, Ellen C; Malp...
# 66             3  Guendelsberger, John; Adkins-Blanch, Charles K...
# 67             3  Grant, Edward R.; Mullane, Hugh G.; RILEY, KEV...
# 68             1                                 Goodwin, Deborah K
# 69             3  Goodwin, Deborah K.; Greer, Anne J.; Donovan, ...
# 70             2  Hunsucker, Keith; Creppy, Michael J; Liebowitz...
# 71             3  Greer, Anne J.; Wendtland, Linda S.; Crossett,...
# 72             3  Guendelsberger, John; Kendall Clark, Molly; Gr...
# 73             1                                    O'Connor, Blair
# 74             2  Gemoets, Marcos; Hunsucker, Keith; Morris, Daniel
# 75             3  Donovan, Teresa L.; Wendtland, Linda S.; Cross...
# 76             3  Greer, Anne J.; Donovan, Teresa L.; Pepper, S....
# 77             1                                    Grant, Edward R
# 78             1                                   Grant, Edward R.
# 79             1                                   Wilson, Earle B.
# 80             0                                   Grant, Edward R.
# 81             3  Gemoets, Marcos; Creppy Michael J; Liebowitz, ...
# 82             3  Adkins-Blanch, Charles K.; Greer, Anne J.; Mil...
# 83             3  Wilson, Earle B.; Swanwick, Daniel L.; Goodwin...
# 84             3  Greer, Anne J; Wendtland, Linda S; Donovan, Te...
# 85             3  Geller, Joan B; Adkins-Blanch, Charles K.; Kel...
# 86             3  Guendelsberger, John; O'Leary, Brian M.; Grant...
# 87             3  Crossett, John P.; Wendtland, Linda S.; Greer,...
# 88             3  Grant, Edward R.; Guendelsberger, John; Kendal...
# 89             3  Pauley, Roger; Wendtland, Linda S.; Greer, Ann...
# 90             2  O'Connor, Blair; Donovan, Teresa L.; Foote, Me...
# 91             1                                Pepper, S. Kathleen
# 92             3  Pauley, Roger; Guendelsberger, John; Geller, J...
# 93             3  Pauley, Roger; Greer, Anne J.; Wendtland, Lind...
# 94             3  O'Connor, Blair; Wilson, Earle B.; Donovan, Te...
# 95             3  Adkins-Blanch, Charles K.; Greer, Anne J.; O'H...
# 96             3  Gemoets, Marcos; Liebowitz, Ellen C; Creppy, M...
# 97             3  Adkins-Blanch, Charles K.; Cole, Patricia A.; ...
# 98             3  Creppy, Michael J.; Liebowitz, Ellen C; Mullan...
# 99             1                                   Grant, Edward R.
# 100            3  Malphrus, Garry D.; O'Connor, Blair; Donovan, ...
# 101            3  Crossett, John P.; Wendtland, Linda S.; Greer,...
# 102            0                                Monsky, Megan Foote
# 103            3  Pauley, Roger; Wendtland, Linda S.; Donovan, T...
# 104            2  Goodwin, Deborah K.; Pepper, S. Kathleen; Dono...
# 105            1                                       Noferi, Mark
# 106            0                                MONSKY, MEGAN FOOTE
# 107            3  Grant, Edward R.; Guendelsberger, John; Kendal...
# 108            3   Cole, Patricia A.; Greer, Anne J.; Pauley, Roger
#
#      num_panel_members
# 0                    1
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# 5                    3
# 6                    3
# 7                    3
# 8                    3
# 9                    1
# 10                   3
# 11                   1
# 12                   3
# 13                   3
# 14                   3
# 15                   2
# 16                   3
# 17                   3
# 18                   3
# 19                   3
# 20                   3
# 21                   3
# 22                   3
# 23                   3
# 24                   1
# 25                   3
# 26                   1
# 27                   3
# 28                   3
# 29                   3
# 30                   3
# 31                   3
# 32                   1
# 33                   3
# 34                   3
# 35                   3
# 36                   3
# 37                   3
# 38                   3
# 39                   3
# 40                   1
# 41                   1
# 42                   3
# 43                   3
# 44                   3
# 45                   3
# 46                   3
# 47                   1
# 48                   3
# 49                   3
# 50                   3
# 51                   3
# 52                   1
# 53                   1
# 54                   3
# 55                   3
# 56                   3
# 57                   3
# 58                   3
# 59                   3
# 60                   1
# 61                   3
# 62                   3
# 63                   3
# 64                   3
# 65                   3
# 66                   3
# 67                   3
# 68                   1
# 69                   3
# 70                   3
# 71                   3
# 72                   3
# 73                   1
# 74                   3
# 75                   3
# 76                   3
# 77                   1
# 78                   1
# 79                   1
# 80                   1
# 81                   3
# 82                   3
# 83                   3
# 84                   3
# 85                   3
# 86                   3
# 87                   3
# 88                   3
# 89                   3
# 90                   3
# 91                   1
# 92                   3
# 93                   3
# 94                   3
# 95                   3
# 96                   3
# 97                   3
# 98                   3
# 99                   1
# 100                  3
# 101                  3
# 102                  1
# 103                  3
# 104                  3
# 105                  1
# 106                  1
# 107                  3
# 108                  3

# %% [markdown]
# # The Phrase Matcher with two patterns for each name is able two find 271 of the 280 panel members, or approximately 97%

# %%
df_merged.num_members.sum(), df_merged.num_panel_members.sum()
# Out:
# (271, 280)
